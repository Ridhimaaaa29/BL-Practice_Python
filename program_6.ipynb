# %% [markdown]
# Handling user error

# %%
def calculate_sum(x: int, y: int):
    """Returns the sum of two numbers."""
    return x + y

# 4: Type conversion from str to int
# 5: Handling bad user inputs
# Bad: Not handling the exact error occurred

try:
    total_sum = int(input("Enter value for Total Sum "))
    bonus_points = int(input("Enter value for Bonus Points "))

    print(
        f"Data Type of total_sum is {type(total_sum)} and \n"
        f"bonus_points is {type(bonus_points)}"
    )

    final_score = calculate_sum(total_sum, bonus_points)

    print(f"Final Score is {final_score}")

except:
    print("Try Again and Enter a Proper Value ")

# %% [markdown]
# Handling exact user error

# %%
# Defining proper function parameter data type
def calculate_sum(x: int, y: int):
    """
    Returns the sum of two numbers.
    """
    return x + y

# Handling the exact error occurred

try:
    total_sum = int(input("Enter value for Total Sum "))
    bonus_points = int(input("Enter value for Bonus Points "))

    print(
        f"Data Type of total_sum is {type(total_sum)} and \n"
        f"bonus_points is {type(bonus_points)}"
    )

    final_score = calculate_sum(total_sum, bonus_points)

    print(f"Final Score is {final_score}")

except ValueError as err:
    print(f"Oops! Got Error: {err},\nThat was no valid input. Try again...")

except:
    print("Try Again and Enter a Proper Value ")
