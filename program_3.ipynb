# %% [markdown]
# Defining a function

# %%
def add(x, y):
    return x + y

total_sum = 10
bonus_points = 20
final_score = add(total_sum, bonus_points)
print(f"Final score is : {final_score}")
# Out:
# Final score is : 30
