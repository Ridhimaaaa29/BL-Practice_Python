# %% [markdown]
# ### Prog 1: OOPS banner

# %% [markdown]
# ##### Description - This program demonstrates the use of the `print()` function to create an **OOPS** banner using asterisks (`*`) and spaces. It helps understand formatted console output and character pattern printing.

# %%
# Use print function with 9 Characters of Space ' ' or '*' for each letter
# i.e. O, O, P, S and Use 9 Print Statements


print('   ***   ',' ',' ','   ***   ',' ',' ','****** ',' ',' ','***** ')
print(' **   ** ',' ',' ',' **   ** ',' ',' ','**   **',' ',' ','**    ')
print('**     **',' ',' ','**     **',' ',' ','**   **',' ',' ','**    ')
print('**     **',' ',' ','**     **',' ',' ','**   **',' ',' ','**    ')
print('**     **',' ',' ','**     **',' ',' ','****** ',' ',' ',' ***  ')
print('**     **',' ',' ','**     **',' ',' ','**     ',' ',' ','   ** ')
print('**     **',' ',' ','**     **',' ',' ','**     ',' ',' ','    **')
print(' **   ** ',' ',' ',' **   ** ',' ',' ','**     ',' ',' ','   ** ')
print('   ***   ',' ',' ','   ***   ',' ',' ','**     ',' ',' ','***** ')
# Out:
#    ***           ***        ******      *****
#  **   **       **   **      **   **     **
# **     **     **     **     **   **     **
# **     **     **     **     **   **     **
# **     **     **     **     ******       ***
# **     **     **     **     **             **
# **     **     **     **     **              **
#  **   **       **   **      **             **
#    ***           ***        **          *****
